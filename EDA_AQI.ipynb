# %%
import numpy as np
import pandas as pd
import scipy as sc
import matplotlib.pyplot as plt
import statsmodels.api as sm
import seaborn as sns
import statistics as s
import sklearn

# %%
df=pd.read_csv('E:/Downloads/data-gov.csv')
df.head(40)
# Out:
#     id country              state               city  \
# 0    1   India     Andhra_Pradesh          Amaravati
# 1    2   India     Andhra_Pradesh          Amaravati
# 2    3   India     Andhra_Pradesh          Amaravati
# 3    4   India     Andhra_Pradesh          Amaravati
# 4    5   India     Andhra_Pradesh          Amaravati
# 5    6   India     Andhra_Pradesh          Amaravati
# 6    7   India     Andhra_Pradesh          Amaravati
# 7    8   India     Andhra_Pradesh  Rajamahendravaram
# 8    9   India     Andhra_Pradesh  Rajamahendravaram
# 9   10   India     Andhra_Pradesh  Rajamahendravaram
# 10  11   India     Andhra_Pradesh  Rajamahendravaram
# 11  12   India     Andhra_Pradesh  Rajamahendravaram
# 12  13   India     Andhra_Pradesh  Rajamahendravaram
# 13  14   India     Andhra_Pradesh  Rajamahendravaram
# 14  15   India     Andhra_Pradesh           Tirupati
# 15  16   India     Andhra_Pradesh           Tirupati
# 16  17   India     Andhra_Pradesh           Tirupati
# 17  18   India     Andhra_Pradesh           Tirupati
# 18  19   India     Andhra_Pradesh           Tirupati
# 19  20   India     Andhra_Pradesh           Tirupati
# 20  21   India     Andhra_Pradesh           Tirupati
# 21  22   India     Andhra_Pradesh      Visakhapatnam
# 22  23   India     Andhra_Pradesh      Visakhapatnam
# 23  24   India     Andhra_Pradesh      Visakhapatnam
# 24  25   India     Andhra_Pradesh      Visakhapatnam
# 25  26   India     Andhra_Pradesh      Visakhapatnam
# 26  27   India     Andhra_Pradesh      Visakhapatnam
# 27  28   India     Andhra_Pradesh      Visakhapatnam
# 28  29   India  Arunachal_Pradesh         Naharlagun
# 29  30   India  Arunachal_Pradesh         Naharlagun
# 30  31   India  Arunachal_Pradesh         Naharlagun
# 31  32   India  Arunachal_Pradesh         Naharlagun
# 32  33   India  Arunachal_Pradesh         Naharlagun
# 33  34   India  Arunachal_Pradesh         Naharlagun
# 34  35   India  Arunachal_Pradesh         Naharlagun
# 35  36   India              Assam           Guwahati
# 36  37   India              Assam           Guwahati
# 37  38   India              Assam           Guwahati
# 38  39   India              Assam           Guwahati
# 39  40   India              Assam           Guwahati
#
#                                            station          last_update  \
# 0                   Secretariat, Amaravati - APPCB  10-02-2022 12:00:00
# 1                   Secretariat, Amaravati - APPCB  10-02-2022 12:00:00
# 2                   Secretariat, Amaravati - APPCB  10-02-2022 12:00:00
# 3                   Secretariat, Amaravati - APPCB  10-02-2022 12:00:00
# 4                   Secretariat, Amaravati - APPCB  10-02-2022 12:00:00
# 5                   Secretariat, Amaravati - APPCB  10-02-2022 12:00:00
# 6                   Secretariat, Amaravati - APPCB  10-02-2022 12:00:00
# 7   Anand Kala Kshetram, Rajamahendravaram - APPCB  10-02-2022 12:00:00
# 8   Anand Kala Kshetram, Rajamahendravaram - APPCB  10-02-2022 12:00:00
# 9   Anand Kala Kshetram, Rajamahendravaram - APPCB  10-02-2022 12:00:00
# 10  Anand Kala Kshetram, Rajamahendravaram - APPCB  10-02-2022 12:00:00
# 11  Anand Kala Kshetram, Rajamahendravaram - APPCB  10-02-2022 12:00:00
# 12  Anand Kala Kshetram, Rajamahendravaram - APPCB  10-02-2022 12:00:00
# 13  Anand Kala Kshetram, Rajamahendravaram - APPCB  10-02-2022 12:00:00
# 14                      Tirumala, Tirupati - APPCB  10-02-2022 12:00:00
# 15                      Tirumala, Tirupati - APPCB  10-02-2022 12:00:00
# 16                      Tirumala, Tirupati - APPCB  10-02-2022 12:00:00
# 17                      Tirumala, Tirupati - APPCB  10-02-2022 12:00:00
# 18                      Tirumala, Tirupati - APPCB  10-02-2022 12:00:00
# 19                      Tirumala, Tirupati - APPCB  10-02-2022 12:00:00
# 20                      Tirumala, Tirupati - APPCB  10-02-2022 12:00:00
# 21          GVM Corporation, Visakhapatnam - APPCB  10-02-2022 12:00:00
# 22          GVM Corporation, Visakhapatnam - APPCB  10-02-2022 12:00:00
# 23          GVM Corporation, Visakhapatnam - APPCB  10-02-2022 12:00:00
# 24          GVM Corporation, Visakhapatnam - APPCB  10-02-2022 12:00:00
# 25          GVM Corporation, Visakhapatnam - APPCB  10-02-2022 12:00:00
# 26          GVM Corporation, Visakhapatnam - APPCB  10-02-2022 12:00:00
# 27          GVM Corporation, Visakhapatnam - APPCB  10-02-2022 12:00:00
# 28                 Naharlagun, Naharlagun - APSPCB  10-02-2022 12:00:00
# 29                 Naharlagun, Naharlagun - APSPCB  10-02-2022 12:00:00
# 30                 Naharlagun, Naharlagun - APSPCB  10-02-2022 12:00:00
# 31                 Naharlagun, Naharlagun - APSPCB  10-02-2022 12:00:00
# 32                 Naharlagun, Naharlagun - APSPCB  10-02-2022 12:00:00
# 33                 Naharlagun, Naharlagun - APSPCB  10-02-2022 12:00:00
# 34                 Naharlagun, Naharlagun - APSPCB  10-02-2022 12:00:00
# 35                     Pan Bazaar, Guwahati - APCB  10-02-2022 12:00:00
# 36                     Pan Bazaar, Guwahati - APCB  10-02-2022 12:00:00
# 37                     Pan Bazaar, Guwahati - APCB  10-02-2022 12:00:00
# 38                     Pan Bazaar, Guwahati - APCB  10-02-2022 12:00:00
# 39                     Pan Bazaar, Guwahati - APCB  10-02-2022 12:00:00
#
#    pollutant_id  pollutant_min  pollutant_max  pollutant_avg  pollutant_unit
# 0         PM2.5           50.0           88.0           72.0             NaN
# 1          PM10           63.0           93.0           78.0             NaN
# 2           NO2            8.0           27.0           14.0             NaN
# 3           NH3            3.0            4.0            4.0             NaN
# 4           SO2           11.0           20.0           16.0             NaN
# 5            CO            2.0           43.0           23.0             NaN
# 6         OZONE           39.0           79.0           58.0             NaN
# 7         PM2.5           62.0          136.0           85.0             NaN
# 8          PM10           85.0          128.0          104.0             NaN
# 9           NO2           10.0           33.0           18.0             NaN
# 10          NH3            3.0            5.0            4.0             NaN
# 11          SO2            2.0           12.0            7.0             NaN
# 12           CO            4.0           40.0           25.0             NaN
# 13        OZONE           41.0           70.0           53.0             NaN
# 14        PM2.5           50.0           79.0           64.0             NaN
# 15         PM10           55.0           84.0           68.0             NaN
# 16          NO2            7.0           41.0           23.0             NaN
# 17          NH3            1.0            2.0            1.0             NaN
# 18          SO2            5.0           10.0            8.0             NaN
# 19           CO           35.0           49.0           40.0             NaN
# 20        OZONE           27.0           47.0           34.0             NaN
# 21        PM2.5           55.0          301.0          133.0             NaN
# 22         PM10           86.0          325.0          162.0             NaN
# 23          NO2           13.0          150.0           69.0             NaN
# 24          NH3            1.0            6.0            3.0             NaN
# 25          SO2            2.0           21.0           14.0             NaN
# 26           CO            5.0          126.0           40.0             NaN
# 27        OZONE            9.0          141.0           60.0             NaN
# 28        PM2.5            NaN            NaN            NaN             NaN
# 29         PM10            NaN            NaN            NaN             NaN
# 30          NO2            NaN            NaN            NaN             NaN
# 31          NH3            NaN            NaN            NaN             NaN
# 32          SO2            NaN            NaN            NaN             NaN
# 33           CO            NaN            NaN            NaN             NaN
# 34        OZONE            NaN            NaN            NaN             NaN
# 35        PM2.5           56.0          349.0          204.0             NaN
# 36         PM10           45.0          269.0          129.0             NaN
# 37          NO2            2.0           16.0            8.0             NaN
# 38          NH3            1.0           12.0            5.0             NaN
# 39          SO2           18.0           39.0           25.0             NaN

# %%
df.columns
# Out:
# Index(['id', 'country', 'state', 'city', 'station', 'last_update',
#        'pollutant_id', 'pollutant_min', 'pollutant_max', 'pollutant_avg',
#        'pollutant_unit'],
#       dtype='object')

# %%
df.shape
# Out:
# (2079, 11)

# %%
a=df.iloc[0:2079,3:11]

# %%
a
# Out:
#            city                             station          last_update  \
# 0     Amaravati      Secretariat, Amaravati - APPCB  10-02-2022 12:00:00
# 1     Amaravati      Secretariat, Amaravati - APPCB  10-02-2022 12:00:00
# 2     Amaravati      Secretariat, Amaravati - APPCB  10-02-2022 12:00:00
# 3     Amaravati      Secretariat, Amaravati - APPCB  10-02-2022 12:00:00
# 4     Amaravati      Secretariat, Amaravati - APPCB  10-02-2022 12:00:00
# ...         ...                                 ...                  ...
# 2074   Siliguri  Ward-32 Bapupara, Siliguri - WBPCB  10-02-2022 12:00:00
# 2075   Siliguri  Ward-32 Bapupara, Siliguri - WBPCB  10-02-2022 12:00:00
# 2076   Siliguri  Ward-32 Bapupara, Siliguri - WBPCB  10-02-2022 12:00:00
# 2077   Siliguri  Ward-32 Bapupara, Siliguri - WBPCB  10-02-2022 12:00:00
# 2078   Siliguri  Ward-32 Bapupara, Siliguri - WBPCB  10-02-2022 12:00:00
#
#      pollutant_id  pollutant_min  pollutant_max  pollutant_avg  pollutant_unit
# 0           PM2.5           50.0           88.0           72.0             NaN
# 1            PM10           63.0           93.0           78.0             NaN
# 2             NO2            8.0           27.0           14.0             NaN
# 3             NH3            3.0            4.0            4.0             NaN
# 4             SO2           11.0           20.0           16.0             NaN
# ...           ...            ...            ...            ...             ...
# 2074          NO2           14.0           91.0           51.0             NaN
# 2075          NH3           11.0           17.0           13.0             NaN
# 2076          SO2            3.0            6.0            5.0             NaN
# 2077           CO           23.0          104.0           32.0             NaN
# 2078        OZONE            9.0           92.0           26.0             NaN
#
# [2079 rows x 8 columns]

# %%
b=a.iloc[0:2079,2:11]

# %%
b
# Out:
#               last_update pollutant_id  pollutant_min  pollutant_max  \
# 0     10-02-2022 12:00:00        PM2.5           50.0           88.0
# 1     10-02-2022 12:00:00         PM10           63.0           93.0
# 2     10-02-2022 12:00:00          NO2            8.0           27.0
# 3     10-02-2022 12:00:00          NH3            3.0            4.0
# 4     10-02-2022 12:00:00          SO2           11.0           20.0
# ...                   ...          ...            ...            ...
# 2074  10-02-2022 12:00:00          NO2           14.0           91.0
# 2075  10-02-2022 12:00:00          NH3           11.0           17.0
# 2076  10-02-2022 12:00:00          SO2            3.0            6.0
# 2077  10-02-2022 12:00:00           CO           23.0          104.0
# 2078  10-02-2022 12:00:00        OZONE            9.0           92.0
#
#       pollutant_avg  pollutant_unit
# 0              72.0             NaN
# 1              78.0             NaN
# 2              14.0             NaN
# 3               4.0             NaN
# 4              16.0             NaN
# ...             ...             ...
# 2074           51.0             NaN
# 2075           13.0             NaN
# 2076            5.0             NaN
# 2077           32.0             NaN
# 2078           26.0             NaN
#
# [2079 rows x 6 columns]

# %%
b.loc[50]
# Out:
# last_update       10-02-2022 12:00:00
# pollutant_id                     PM10
# pollutant_min                    78.0
# pollutant_max                   500.0
# pollutant_avg                   182.0
# pollutant_unit                    NaN
# Name: 50, dtype: object

# %%
b.head(50)
# Out:
#             last_update pollutant_id  pollutant_min  pollutant_max  \
# 0   10-02-2022 12:00:00        PM2.5           50.0           88.0
# 1   10-02-2022 12:00:00         PM10           63.0           93.0
# 2   10-02-2022 12:00:00          NO2            8.0           27.0
# 3   10-02-2022 12:00:00          NH3            3.0            4.0
# 4   10-02-2022 12:00:00          SO2           11.0           20.0
# 5   10-02-2022 12:00:00           CO            2.0           43.0
# 6   10-02-2022 12:00:00        OZONE           39.0           79.0
# 7   10-02-2022 12:00:00        PM2.5           62.0          136.0
# 8   10-02-2022 12:00:00         PM10           85.0          128.0
# 9   10-02-2022 12:00:00          NO2           10.0           33.0
# 10  10-02-2022 12:00:00          NH3            3.0            5.0
# 11  10-02-2022 12:00:00          SO2            2.0           12.0
# 12  10-02-2022 12:00:00           CO            4.0           40.0
# 13  10-02-2022 12:00:00        OZONE           41.0           70.0
# 14  10-02-2022 12:00:00        PM2.5           50.0           79.0
# 15  10-02-2022 12:00:00         PM10           55.0           84.0
# 16  10-02-2022 12:00:00          NO2            7.0           41.0
# 17  10-02-2022 12:00:00          NH3            1.0            2.0
# 18  10-02-2022 12:00:00          SO2            5.0           10.0
# 19  10-02-2022 12:00:00           CO           35.0           49.0
# 20  10-02-2022 12:00:00        OZONE           27.0           47.0
# 21  10-02-2022 12:00:00        PM2.5           55.0          301.0
# 22  10-02-2022 12:00:00         PM10           86.0          325.0
# 23  10-02-2022 12:00:00          NO2           13.0          150.0
# 24  10-02-2022 12:00:00          NH3            1.0            6.0
# 25  10-02-2022 12:00:00          SO2            2.0           21.0
# 26  10-02-2022 12:00:00           CO            5.0          126.0
# 27  10-02-2022 12:00:00        OZONE            9.0          141.0
# 28  10-02-2022 12:00:00        PM2.5            NaN            NaN
# 29  10-02-2022 12:00:00         PM10            NaN            NaN
# 30  10-02-2022 12:00:00          NO2            NaN            NaN
# 31  10-02-2022 12:00:00          NH3            NaN            NaN
# 32  10-02-2022 12:00:00          SO2            NaN            NaN
# 33  10-02-2022 12:00:00           CO            NaN            NaN
# 34  10-02-2022 12:00:00        OZONE            NaN            NaN
# 35  10-02-2022 12:00:00        PM2.5           56.0          349.0
# 36  10-02-2022 12:00:00         PM10           45.0          269.0
# 37  10-02-2022 12:00:00          NO2            2.0           16.0
# 38  10-02-2022 12:00:00          NH3            1.0           12.0
# 39  10-02-2022 12:00:00          SO2           18.0           39.0
# 40  10-02-2022 12:00:00           CO           12.0          108.0
# 41  10-02-2022 12:00:00        OZONE            1.0           22.0
# 42  10-02-2022 12:00:00        PM2.5           42.0          357.0
# 43  10-02-2022 12:00:00         PM10           39.0          263.0
# 44  10-02-2022 12:00:00          NO2            3.0            4.0
# 45  10-02-2022 12:00:00          NH3            2.0            4.0
# 46  10-02-2022 12:00:00          SO2            8.0           11.0
# 47  10-02-2022 12:00:00           CO           17.0           72.0
# 48  10-02-2022 12:00:00        OZONE           10.0           33.0
# 49  10-02-2022 12:00:00        PM2.5           70.0          488.0
#
#     pollutant_avg  pollutant_unit
# 0            72.0             NaN
# 1            78.0             NaN
# 2            14.0             NaN
# 3             4.0             NaN
# 4            16.0             NaN
# 5            23.0             NaN
# 6            58.0             NaN
# 7            85.0             NaN
# 8           104.0             NaN
# 9            18.0             NaN
# 10            4.0             NaN
# 11            7.0             NaN
# 12           25.0             NaN
# 13           53.0             NaN
# 14           64.0             NaN
# 15           68.0             NaN
# 16           23.0             NaN
# 17            1.0             NaN
# 18            8.0             NaN
# 19           40.0             NaN
# 20           34.0             NaN
# 21          133.0             NaN
# 22          162.0             NaN
# 23           69.0             NaN
# 24            3.0             NaN
# 25           14.0             NaN
# 26           40.0             NaN
# 27           60.0             NaN
# 28            NaN             NaN
# 29            NaN             NaN
# 30            NaN             NaN
# 31            NaN             NaN
# 32            NaN             NaN
# 33            NaN             NaN
# 34            NaN             NaN
# 35          204.0             NaN
# 36          129.0             NaN
# 37            8.0             NaN
# 38            5.0             NaN
# 39           25.0             NaN
# 40           39.0             NaN
# 41            5.0             NaN
# 42          199.0             NaN
# 43          132.0             NaN
# 44            3.0             NaN
# 45            3.0             NaN
# 46           10.0             NaN
# 47           48.0             NaN
# 48           21.0             NaN
# 49          204.0             NaN

# %%
print(b.isnull())
# Out:
#       last_update  pollutant_id  pollutant_min  pollutant_max  pollutant_avg  \
# 0           False         False          False          False          False
# 1           False         False          False          False          False
# 2           False         False          False          False          False
# 3           False         False          False          False          False
# 4           False         False          False          False          False
# ...           ...           ...            ...            ...            ...
# 2074        False         False          False          False          False
# 2075        False         False          False          False          False
# 2076        False         False          False          False          False
# 2077        False         False          False          False          False
# 2078        False         False          False          False          False
#
#       pollutant_unit
# 0               True
# 1               True
# 2               True
# 3               True
# 4               True
# ...              ...
# 2074            True
# 2075            True
# 2076            True
# 2077            True
# 2078            True
#
# [2079 rows x 6 columns]

# %%
b.isnull().sum()
# Out:
# last_update          0
# pollutant_id         0
# pollutant_min      151
# pollutant_max      151
# pollutant_avg      151
# pollutant_unit    2079
# dtype: int64

# %%
b.dropna(subset=['pollutant_min','pollutant_max','pollutant_avg'], inplace=True)

# %%
b
# Out:
#               last_update pollutant_id  pollutant_min  pollutant_max  \
# 0     10-02-2022 12:00:00        PM2.5           50.0           88.0
# 1     10-02-2022 12:00:00         PM10           63.0           93.0
# 2     10-02-2022 12:00:00          NO2            8.0           27.0
# 3     10-02-2022 12:00:00          NH3            3.0            4.0
# 4     10-02-2022 12:00:00          SO2           11.0           20.0
# ...                   ...          ...            ...            ...
# 2074  10-02-2022 12:00:00          NO2           14.0           91.0
# 2075  10-02-2022 12:00:00          NH3           11.0           17.0
# 2076  10-02-2022 12:00:00          SO2            3.0            6.0
# 2077  10-02-2022 12:00:00           CO           23.0          104.0
# 2078  10-02-2022 12:00:00        OZONE            9.0           92.0
#
#       pollutant_avg  pollutant_unit
# 0              72.0             NaN
# 1              78.0             NaN
# 2              14.0             NaN
# 3               4.0             NaN
# 4              16.0             NaN
# ...             ...             ...
# 2074           51.0             NaN
# 2075           13.0             NaN
# 2076            5.0             NaN
# 2077           32.0             NaN
# 2078           26.0             NaN
#
# [1928 rows x 6 columns]

# %%
b.isnull().sum()
# Out:
# last_update          0
# pollutant_id         0
# pollutant_min        0
# pollutant_max        0
# pollutant_avg        0
# pollutant_unit    1928
# dtype: int64

# %%
b.head(50)
# Out:
#             last_update pollutant_id  pollutant_min  pollutant_max  \
# 0   10-02-2022 12:00:00        PM2.5           50.0           88.0
# 1   10-02-2022 12:00:00         PM10           63.0           93.0
# 2   10-02-2022 12:00:00          NO2            8.0           27.0
# 3   10-02-2022 12:00:00          NH3            3.0            4.0
# 4   10-02-2022 12:00:00          SO2           11.0           20.0
# 5   10-02-2022 12:00:00           CO            2.0           43.0
# 6   10-02-2022 12:00:00        OZONE           39.0           79.0
# 7   10-02-2022 12:00:00        PM2.5           62.0          136.0
# 8   10-02-2022 12:00:00         PM10           85.0          128.0
# 9   10-02-2022 12:00:00          NO2           10.0           33.0
# 10  10-02-2022 12:00:00          NH3            3.0            5.0
# 11  10-02-2022 12:00:00          SO2            2.0           12.0
# 12  10-02-2022 12:00:00           CO            4.0           40.0
# 13  10-02-2022 12:00:00        OZONE           41.0           70.0
# 14  10-02-2022 12:00:00        PM2.5           50.0           79.0
# 15  10-02-2022 12:00:00         PM10           55.0           84.0
# 16  10-02-2022 12:00:00          NO2            7.0           41.0
# 17  10-02-2022 12:00:00          NH3            1.0            2.0
# 18  10-02-2022 12:00:00          SO2            5.0           10.0
# 19  10-02-2022 12:00:00           CO           35.0           49.0
# 20  10-02-2022 12:00:00        OZONE           27.0           47.0
# 21  10-02-2022 12:00:00        PM2.5           55.0          301.0
# 22  10-02-2022 12:00:00         PM10           86.0          325.0
# 23  10-02-2022 12:00:00          NO2           13.0          150.0
# 24  10-02-2022 12:00:00          NH3            1.0            6.0
# 25  10-02-2022 12:00:00          SO2            2.0           21.0
# 26  10-02-2022 12:00:00           CO            5.0          126.0
# 27  10-02-2022 12:00:00        OZONE            9.0          141.0
# 35  10-02-2022 12:00:00        PM2.5           56.0          349.0
# 36  10-02-2022 12:00:00         PM10           45.0          269.0
# 37  10-02-2022 12:00:00          NO2            2.0           16.0
# 38  10-02-2022 12:00:00          NH3            1.0           12.0
# 39  10-02-2022 12:00:00          SO2           18.0           39.0
# 40  10-02-2022 12:00:00           CO           12.0          108.0
# 41  10-02-2022 12:00:00        OZONE            1.0           22.0
# 42  10-02-2022 12:00:00        PM2.5           42.0          357.0
# 43  10-02-2022 12:00:00         PM10           39.0          263.0
# 44  10-02-2022 12:00:00          NO2            3.0            4.0
# 45  10-02-2022 12:00:00          NH3            2.0            4.0
# 46  10-02-2022 12:00:00          SO2            8.0           11.0
# 47  10-02-2022 12:00:00           CO           17.0           72.0
# 48  10-02-2022 12:00:00        OZONE           10.0           33.0
# 49  10-02-2022 12:00:00        PM2.5           70.0          488.0
# 50  10-02-2022 12:00:00         PM10           78.0          500.0
# 51  10-02-2022 12:00:00          NO2           43.0          115.0
# 52  10-02-2022 12:00:00          SO2            2.0            9.0
# 53  10-02-2022 12:00:00        OZONE           83.0          184.0
# 54  10-02-2022 12:00:00        PM2.5          117.0          338.0
# 55  10-02-2022 12:00:00         PM10          121.0          197.0
# 56  10-02-2022 12:00:00          NO2           63.0          169.0
#
#     pollutant_avg  pollutant_unit
# 0            72.0             NaN
# 1            78.0             NaN
# 2            14.0             NaN
# 3             4.0             NaN
# 4            16.0             NaN
# 5            23.0             NaN
# 6            58.0             NaN
# 7            85.0             NaN
# 8           104.0             NaN
# 9            18.0             NaN
# 10            4.0             NaN
# 11            7.0             NaN
# 12           25.0             NaN
# 13           53.0             NaN
# 14           64.0             NaN
# 15           68.0             NaN
# 16           23.0             NaN
# 17            1.0             NaN
# 18            8.0             NaN
# 19           40.0             NaN
# 20           34.0             NaN
# 21          133.0             NaN
# 22          162.0             NaN
# 23           69.0             NaN
# 24            3.0             NaN
# 25           14.0             NaN
# 26           40.0             NaN
# 27           60.0             NaN
# 35          204.0             NaN
# 36          129.0             NaN
# 37            8.0             NaN
# 38            5.0             NaN
# 39           25.0             NaN
# 40           39.0             NaN
# 41            5.0             NaN
# 42          199.0             NaN
# 43          132.0             NaN
# 44            3.0             NaN
# 45            3.0             NaN
# 46           10.0             NaN
# 47           48.0             NaN
# 48           21.0             NaN
# 49          204.0             NaN
# 50          182.0             NaN
# 51           59.0             NaN
# 52            4.0             NaN
# 53          107.0             NaN
# 54          235.0             NaN
# 55          145.0             NaN
# 56          108.0             NaN

# %%
b.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2074    False
# 2075    False
# 2076    False
# 2077    False
# 2078    False
# Length: 1928, dtype: bool

# %%
b.duplicated().value_counts()
# Out:
# False    1790
# True      138
# dtype: int64

# %%
fig, ax = plt.subplots(figsize=(10,10))
ax.scatter('pollutant_min', 'pollutant_max', c='pollutant_max', s=50, data=b)
ax.set_xlabel('Minimum Pollution')
ax.set_ylabel('Date');

# %%
sns.set_theme(style="whitegrid")
ax = sns.boxplot(x=b["pollutant_min"])

# %%
sns.set_theme(style="whitegrid")
ax = sns.boxplot(x=b["pollutant_max"])

# %%
sns.set_theme(style="whitegrid")
ax = sns.boxplot(x=b["pollutant_avg"])

# %%
d=b.iloc[:,1:5]

# %%
d
# Out:
#      pollutant_id  pollutant_min  pollutant_max  pollutant_avg
# 0           PM2.5           50.0           88.0           72.0
# 1            PM10           63.0           93.0           78.0
# 2             NO2            8.0           27.0           14.0
# 3             NH3            3.0            4.0            4.0
# 4             SO2           11.0           20.0           16.0
# ...           ...            ...            ...            ...
# 2074          NO2           14.0           91.0           51.0
# 2075          NH3           11.0           17.0           13.0
# 2076          SO2            3.0            6.0            5.0
# 2077           CO           23.0          104.0           32.0
# 2078        OZONE            9.0           92.0           26.0
#
# [1928 rows x 4 columns]

# %%
ax1 = sns.boxplot(x="pollutant_min", y="pollutant_max", data=b)

# %%
var1 = s.variance(d["pollutant_avg"])
var2 = s.variance(d["pollutant_min"])
var3 = s.variance(d["pollutant_max"])

# %%
sns.pairplot(d, height=4)

# %%
e=d.iloc[:,1:4]
e
# Out:
#       pollutant_min  pollutant_max  pollutant_avg
# 0              50.0           88.0           72.0
# 1              63.0           93.0           78.0
# 2               8.0           27.0           14.0
# 3               3.0            4.0            4.0
# 4              11.0           20.0           16.0
# ...             ...            ...            ...
# 2074           14.0           91.0           51.0
# 2075           11.0           17.0           13.0
# 2076            3.0            6.0            5.0
# 2077           23.0          104.0           32.0
# 2078            9.0           92.0           26.0
#
# [1928 rows x 3 columns]

# %%
g = sns.clustermap(e)

# %%
fig, ax1 = plt.subplots(figsize=(10,10))
sns.violinplot('pollutant_min','pollutant_avg', data=e, orient='v')
# Out:
# c:\users\akshat banga\appdata\local\programs\python\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='pollutant_min', ylabel='pollutant_avg'>

# %%
fig, ax1 = plt.subplots(figsize=(10,10))
sns.violinplot('pollutant_max','pollutant_avg', data=e, orient='v')
sns.violinplot('pollutant_min','pollutant_avg', data=e, orient='v')
# Out:
# c:\users\akshat banga\appdata\local\programs\python\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# c:\users\akshat banga\appdata\local\programs\python\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='pollutant_min', ylabel='pollutant_avg'>

# %%
gd=e.groupby('pollutant_avg').agg(['mean','median'])
gd
# Out:
#               pollutant_min        pollutant_max
#                        mean median          mean median
# pollutant_avg
# 1.0                1.000000    1.0      1.920000    2.0
# 2.0                1.390244    1.0      5.024390    3.0
# 3.0                1.977778    2.0      5.622222    4.0
# 4.0                2.595238    3.0      7.214286    5.5
# 5.0                3.060000    3.0     12.480000    8.0
# ...                     ...    ...           ...    ...
# 349.0            247.000000  247.0    438.000000  438.0
# 353.0            306.000000  306.0    415.000000  415.0
# 354.0            303.000000  303.0    404.000000  404.0
# 360.0            243.000000  243.0    437.000000  437.0
# 386.0            338.000000  338.0    443.000000  443.0
#
# [228 rows x 4 columns]

# %%
plt.plot(gd)
# Out:
# [<matplotlib.lines.Line2D at 0x170d572b7f0>,
#  <matplotlib.lines.Line2D at 0x170d572b7c0>,
#  <matplotlib.lines.Line2D at 0x170d572b910>,
#  <matplotlib.lines.Line2D at 0x170d572ba30>]

# %%
sns.FacetGrid(d, hue="pollutant_id", height=5) \
.map(sns.distplot, "pollutant_avg") \
.add_legend()
# Out:
# c:\users\akshat banga\appdata\local\programs\python\python39\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# c:\users\akshat banga\appdata\local\programs\python\python39\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# c:\users\akshat banga\appdata\local\programs\python\python39\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# c:\users\akshat banga\appdata\local\programs\python\python39\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# c:\users\akshat banga\appdata\local\programs\python\python39\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# c:\users\akshat banga\appdata\local\programs\python\python39\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# c:\users\akshat banga\appdata\local\programs\python\python39\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.FacetGrid(d, hue="pollutant_id", height=5) \
.map(sns.distplot, "pollutant_min") \
.add_legend()
# Out:
# c:\users\akshat banga\appdata\local\programs\python\python39\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# c:\users\akshat banga\appdata\local\programs\python\python39\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# c:\users\akshat banga\appdata\local\programs\python\python39\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# c:\users\akshat banga\appdata\local\programs\python\python39\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# c:\users\akshat banga\appdata\local\programs\python\python39\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# c:\users\akshat banga\appdata\local\programs\python\python39\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# c:\users\akshat banga\appdata\local\programs\python\python39\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.FacetGrid(d, hue="pollutant_id", height=5) \
.map(sns.distplot, "pollutant_max") \
.add_legend()
# Out:
# c:\users\akshat banga\appdata\local\programs\python\python39\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# c:\users\akshat banga\appdata\local\programs\python\python39\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# c:\users\akshat banga\appdata\local\programs\python\python39\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# c:\users\akshat banga\appdata\local\programs\python\python39\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# c:\users\akshat banga\appdata\local\programs\python\python39\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# c:\users\akshat banga\appdata\local\programs\python\python39\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# c:\users\akshat banga\appdata\local\programs\python\python39\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
cr = df.iloc[:,:10]

# %%
cr.corr()
# Out:
#                      id  pollutant_min  pollutant_max  pollutant_avg
# id             1.000000      -0.132304      -0.148105      -0.159921
# pollutant_min -0.132304       1.000000       0.734568       0.897181
# pollutant_max -0.148105       0.734568       1.000000       0.924845
# pollutant_avg -0.159921       0.897181       0.924845       1.000000

# %%
plt.figure(figsize=(10,9))
sns.heatmap(cr.corr(),cmap="vlag_r",annot=True,fmt='.2f',linewidths=2, cbar=False)
plt.title("Correlation Matrix")
plt.show()

# %%
b['pollutant_id'].value_counts()
# Out:
# OZONE    287
# NO2      283
# PM10     283
# CO       282
# PM2.5    280
# SO2      273
# NH3      240
# Name: pollutant_id, dtype: int64

# %%
b.loc[(b["pollutant_avg"]<=5),'Pollution Level'] = 'No'
b.loc[(b["pollutant_avg"]>5) & (b["pollutant_avg"]<=40),'Pollution Level'] = 'Moderate'
b.loc[(b["pollutant_avg"]>40) & (b["pollutant_avg"]<=80),'Pollution Level'] = 'Substantial'
b.loc[(b["pollutant_avg"]>80) & (b["pollutant_avg"]<=120),'Pollution Level'] = 'High'
b.loc[(b["pollutant_avg"]>120) & (b["pollutant_avg"]<=160),'Pollution Level'] = 'Worse'
b.loc[(b["pollutant_avg"]>160),'Pollution Level'] = 'Severe'

# %%
h=b.sample(50)

# %%
low = h[h["Pollution Level"] == 'Severe']["pollutant_avg"]
below_av = h[h["Pollution Level"] == 'Worse']["pollutant_avg"]
av = h[h["Pollution Level"] == 'High']["pollutant_avg"]
mod = h[h["Pollution Level"] == 'Substantial']["pollutant_avg"]
good = h[h["Pollution Level"] == 'Moderate']["pollutant_avg"]
minimal = h[h["Pollution Level"] == 'No']["pollutant_avg"]

# %%
f_stats, p_value = sc.stats.f_oneway(low,below_av,av,mod,good,minimal,axis=0)

# %%
print("F-Statistic={0}, P-value={1}".format(f_stats,p_value))
# Out:
# F-Statistic=58.01389583106674, P-value=2.9496550847389514e-18

# %%
pearson,p_value = sc.stats.pearsonr(h["pollutant_min"],h["pollutant_max"])

# %%
print("Pearson Coefficient value={0}, P-value={1}".format(pearson,p_value))
# Out:
# Pearson Coefficient value=0.7775001103139637, P-value=3.12024422192499e-11

# %%
h.columns
# Out:
# Index(['last_update', 'pollutant_id', 'pollutant_min', 'pollutant_max',
#        'pollutant_avg', 'pollutant_unit', 'Pollution Level'],
#       dtype='object')

# %%
y = h['pollutant_avg']
x = h['pollutant_min']

# %%
x = sm.add_constant(x)

# %%
Result=sm.OLS(y,x).fit()

# %%
Result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          pollutant_avg   R-squared:                       0.860
# Model:                            OLS   Adj. R-squared:                  0.857
# Method:                 Least Squares   F-statistic:                     295.0
# Date:                Mon, 14 Feb 2022   Prob (F-statistic):           3.91e-22
# Time:                        20:33:33   Log-Likelihood:                -228.23
# No. Observations:                  50   AIC:                             460.5
# Df Residuals:                      48   BIC:                             464.3
# Df Model:                           1
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const            13.3030      4.331      3.072      0.003       4.596      22.010
# pollutant_min     1.3437      0.078     17.176      0.000       1.186       1.501
# ==============================================================================
# Omnibus:                       27.660   Durbin-Watson:                   1.883
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               46.918
# Skew:                           1.799   Prob(JB):                     6.49e-11
# Kurtosis:                       6.094   Cond. No.                         71.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
h.corr()
# Out:
#                 pollutant_min  pollutant_max  pollutant_avg  pollutant_unit
# pollutant_min        1.000000       0.777500       0.927399             NaN
# pollutant_max        0.777500       1.000000       0.937856             NaN
# pollutant_avg        0.927399       0.937856       1.000000             NaN
# pollutant_unit            NaN            NaN            NaN             NaN

# %%
fig=plt.figure(figsize=(10,9))
sns.heatmap(h.corr(), cmap = 'viridis', annot=True,fmt='.2f',linewidths=2, cbar=False)
plt.title("Correlation Matrix (After Hypothesis Testing)")
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder
enc=LabelEncoder()
b['pollutant_id']=enc.fit_transform(b['pollutant_id'])
b['pollutant_id']
# Out:
# 0       5
# 1       4
# 2       2
# 3       1
# 4       6
#        ..
# 2074    2
# 2075    1
# 2076    6
# 2077    0
# 2078    3
# Name: pollutant_id, Length: 1928, dtype: int32

# %%
y = b['pollutant_avg']
x_new = b.drop(['pollutant_unit','last_update','Pollution Level'],axis=1)
x_new
# Out:
#       pollutant_id  pollutant_min  pollutant_max  pollutant_avg
# 0                5           50.0           88.0           72.0
# 1                4           63.0           93.0           78.0
# 2                2            8.0           27.0           14.0
# 3                1            3.0            4.0            4.0
# 4                6           11.0           20.0           16.0
# ...            ...            ...            ...            ...
# 2074             2           14.0           91.0           51.0
# 2075             1           11.0           17.0           13.0
# 2076             6            3.0            6.0            5.0
# 2077             0           23.0          104.0           32.0
# 2078             3            9.0           92.0           26.0
#
# [1928 rows x 4 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(x_new,y,test_size=0.2,random_state=42)
print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
# Out:
# (1542, 4)
# (386, 4)
# (1542,)
# (386,)

# %%
from sklearn.tree import DecisionTreeClassifier, plot_tree
clf=DecisionTreeClassifier()

# %%
clf.fit(X_train,Y_train)
# Out:
# DecisionTreeClassifier()

# %%
print("Accuracy obtained :",clf.score(X_test,Y_test))
# Out:
# Accuracy obtained : 0.9222797927461139

# %%
from sklearn.linear_model import LinearRegression,Ridge
reg=Ridge(alpha=0.5)

# %%
reg.fit(X_train,Y_train)
# Out:
# Ridge(alpha=0.5)

# %%
reg.score(X_test,Y_test)
# Out:
# 0.9999999999997434

# %%
z1=reg.coef_
z1
# Out:
# array([9.29162372e-08, 1.76628233e-06, 8.80104922e-07, 9.99997559e-01])

# %%
reg.intercept_
# Out:
# -3.507902697208465e-06

# %%
RidgeGraph=pd.Series(z1,X_test.columns)
RidgeGraph
# Out:
# pollutant_id     9.291624e-08
# pollutant_min    1.766282e-06
# pollutant_max    8.801049e-07
# pollutant_avg    9.999976e-01
# dtype: float64

# %%
ax = plt.gca()

ax.plot(Y_test,X_test)
ax.set_xscale("log")
ax.set_xlim(ax.get_xlim()[::-1])  # reverse axis
plt.axis("tight")
plt.show()

# %%
data = [['Decision Tree',0.9222797927461139], ['Ridge Regression',0.9999999999997434]]
summary = pd.DataFrame(data, columns=['Model', 'Accuracy'])
summary
# Out:
#               Model  Accuracy
# 0     Decision Tree   0.92228
# 1  Ridge Regression   1.00000

# %%
sns.pairplot(X_test,hue = "pollutant_id",palette="bright")

# %%
X_test.corr()
plt.figure(figsize=(15,10))
sns.heatmap(X_test.corr(), cmap='gist_earth',annot=True)
plt.title("Correlation Matrix after training data")
# Out:
# Text(0.5, 1.0, 'Correlation Matrix after training data')
